# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('HTRU_2.csv')
df.head()
# Out:
#      140.5625  55.68378214  -0.234571412  -0.699648398  3.199832776  \
# 0  102.507812    58.882430      0.465318     -0.515088     1.677258
# 1  103.015625    39.341649      0.323328      1.051164     3.121237
# 2  136.750000    57.178449     -0.068415     -0.636238     3.642977
# 3   88.726562    40.672225      0.600866      1.123492     1.178930
# 4   93.570312    46.698114      0.531905      0.416721     1.636288
#
#    19.11042633  7.975531794  74.24222492  0
# 0    14.860146    10.576487   127.393580  0
# 1    21.744669     7.735822    63.171909  0
# 2    20.959280     6.896499    53.593661  0
# 3    11.468720    14.269573   252.567306  0
# 4    14.545074    10.621748   131.394004  0

# %%
df.columns=['Mean of the integrated profile','Standard deviation of the integrated profile','Excess kurtosis of the integrated profile','Skewness of the integrated profile','Mean of the DM-SNR curve','Standard deviation of the DM-SNR curve','Excess kurtosis of the DM-SNR curve','Skewness of the DM-SNR curve','target_class']

# %%
df.head()
# Out:
#    Mean of the integrated profile  \
# 0                      102.507812
# 1                      103.015625
# 2                      136.750000
# 3                       88.726562
# 4                       93.570312
#
#    Standard deviation of the integrated profile  \
# 0                                     58.882430
# 1                                     39.341649
# 2                                     57.178449
# 3                                     40.672225
# 4                                     46.698114
#
#    Excess kurtosis of the integrated profile  \
# 0                                   0.465318
# 1                                   0.323328
# 2                                  -0.068415
# 3                                   0.600866
# 4                                   0.531905
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.515088                  1.677258
# 1                            1.051164                  3.121237
# 2                           -0.636238                  3.642977
# 3                            1.123492                  1.178930
# 4                            0.416721                  1.636288
#
#    Standard deviation of the DM-SNR curve  \
# 0                               14.860146
# 1                               21.744669
# 2                               20.959280
# 3                               11.468720
# 4                               14.545074
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                            10.576487                    127.393580
# 1                             7.735822                     63.171909
# 2                             6.896499                     53.593661
# 3                            14.269573                    252.567306
# 4                            10.621748                    131.394004
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df.describe()
# Out:
#        Mean of the integrated profile  \
# count                    17897.000000
# mean                       111.078321
# std                         25.652705
# min                          5.812500
# 25%                        100.929688
# 50%                        115.078125
# 75%                        127.085938
# max                        192.617188
#
#        Standard deviation of the integrated profile  \
# count                                  17897.000000
# mean                                      46.549021
# std                                        6.843040
# min                                       24.772042
# 25%                                       42.375426
# 50%                                       46.946435
# 75%                                       51.022887
# max                                       98.778911
#
#        Excess kurtosis of the integrated profile  \
# count                               17897.000000
# mean                                    0.477897
# std                                     1.064056
# min                                    -1.876011
# 25%                                     0.027108
# 50%                                     0.223241
# 75%                                     0.473349
# max                                     8.069522
#
#        Skewness of the integrated profile  Mean of the DM-SNR curve  \
# count                        17897.000000              17897.000000
# mean                             1.770417                 12.614926
# std                              6.168058                 29.473637
# min                             -1.791886                  0.213211
# 25%                             -0.188528                  1.923077
# 50%                              0.198736                  2.801839
# 75%                              0.928206                  5.464883
# max                             68.101622                223.392140
#
#        Standard deviation of the DM-SNR curve  \
# count                            17897.000000
# mean                                26.326918
# std                                 19.471042
# min                                  7.370432
# 25%                                 14.437330
# 50%                                 18.459977
# 75%                                 28.428152
# max                                110.642211
#
#        Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# count                         17897.000000                  17897.000000
# mean                              8.303574                    104.859419
# std                               4.506217                    106.517270
# min                              -3.139270                     -1.976976
# 25%                               5.781485                     34.957119
# 50%                               8.433872                     83.068996
# 75%                              10.702973                    139.310905
# max                              34.539844                   1191.000837
#
#        target_class
# count   17897.00000
# mean        0.09158
# std         0.28844
# min         0.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max         1.00000

# %%
df.corr()
# Out:
#                                               Mean of the integrated profile  \
# Mean of the integrated profile                                      1.000000
# Standard deviation of the integrated profile                        0.547099
# Excess kurtosis of the integrated profile                          -0.873899
# Skewness of the integrated profile                                 -0.738780
# Mean of the DM-SNR curve                                           -0.298832
# Standard deviation of the DM-SNR curve                             -0.307005
# Excess kurtosis of the DM-SNR curve                                 0.234345
# Skewness of the DM-SNR curve                                        0.144057
# target_class                                                       -0.673187
#
#                                               Standard deviation of the integrated profile  \
# Mean of the integrated profile                                                    0.547099
# Standard deviation of the integrated profile                                      1.000000
# Excess kurtosis of the integrated profile                                        -0.521418
# Skewness of the integrated profile                                               -0.539792
# Mean of the DM-SNR curve                                                          0.006893
# Standard deviation of the DM-SNR curve                                           -0.047606
# Excess kurtosis of the DM-SNR curve                                               0.029436
# Skewness of the DM-SNR curve                                                      0.027714
# target_class                                                                     -0.363704
#
#                                               Excess kurtosis of the integrated profile  \
# Mean of the integrated profile                                                -0.873899
# Standard deviation of the integrated profile                                  -0.521418
# Excess kurtosis of the integrated profile                                      1.000000
# Skewness of the integrated profile                                             0.945730
# Mean of the DM-SNR curve                                                       0.414362
# Standard deviation of the DM-SNR curve                                         0.432873
# Excess kurtosis of the DM-SNR curve                                           -0.341216
# Skewness of the DM-SNR curve                                                  -0.214505
# target_class                                                                   0.791592
#
#                                               Skewness of the integrated profile  \
# Mean of the integrated profile                                         -0.738780
# Standard deviation of the integrated profile                           -0.539792
# Excess kurtosis of the integrated profile                               0.945730
# Skewness of the integrated profile                                      1.000000
# Mean of the DM-SNR curve                                                0.412052
# Standard deviation of the DM-SNR curve                                  0.415135
# Excess kurtosis of the DM-SNR curve                                    -0.328846
# Skewness of the DM-SNR curve                                           -0.204790
# target_class                                                            0.709526
#
#                                               Mean of the DM-SNR curve  \
# Mean of the integrated profile                               -0.298832
# Standard deviation of the integrated profile                  0.006893
# Excess kurtosis of the integrated profile                     0.414362
# Skewness of the integrated profile                            0.412052
# Mean of the DM-SNR curve                                      1.000000
# Standard deviation of the DM-SNR curve                        0.796554
# Excess kurtosis of the DM-SNR curve                          -0.615974
# Skewness of the DM-SNR curve                                 -0.354276
# target_class                                                  0.400873
#
#                                               Standard deviation of the DM-SNR curve  \
# Mean of the integrated profile                                             -0.307005
# Standard deviation of the integrated profile                               -0.047606
# Excess kurtosis of the integrated profile                                   0.432873
# Skewness of the integrated profile                                          0.415135
# Mean of the DM-SNR curve                                                    0.796554
# Standard deviation of the DM-SNR curve                                      1.000000
# Excess kurtosis of the DM-SNR curve                                        -0.809791
# Skewness of the DM-SNR curve                                               -0.575809
# target_class                                                                0.491532
#
#                                               Excess kurtosis of the DM-SNR curve  \
# Mean of the integrated profile                                           0.234345
# Standard deviation of the integrated profile                             0.029436
# Excess kurtosis of the integrated profile                               -0.341216
# Skewness of the integrated profile                                      -0.328846
# Mean of the DM-SNR curve                                                -0.615974
# Standard deviation of the DM-SNR curve                                  -0.809791
# Excess kurtosis of the DM-SNR curve                                      1.000000
# Skewness of the DM-SNR curve                                             0.923744
# target_class                                                            -0.390819
#
#                                               Skewness of the DM-SNR curve  \
# Mean of the integrated profile                                    0.144057
# Standard deviation of the integrated profile                      0.027714
# Excess kurtosis of the integrated profile                        -0.214505
# Skewness of the integrated profile                               -0.204790
# Mean of the DM-SNR curve                                         -0.354276
# Standard deviation of the DM-SNR curve                           -0.575809
# Excess kurtosis of the DM-SNR curve                               0.923744
# Skewness of the DM-SNR curve                                      1.000000
# target_class                                                     -0.259123
#
#                                               target_class
# Mean of the integrated profile                   -0.673187
# Standard deviation of the integrated profile     -0.363704
# Excess kurtosis of the integrated profile         0.791592
# Skewness of the integrated profile                0.709526
# Mean of the DM-SNR curve                          0.400873
# Standard deviation of the DM-SNR curve            0.491532
# Excess kurtosis of the DM-SNR curve              -0.390819
# Skewness of the DM-SNR curve                     -0.259123
# target_class                                      1.000000

# %%
labels = df.target_class.values
df.drop(["target_class"],axis=1,inplace=True)

# %%
features = df.values
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
feature_scaled = scaler.fit_transform(features)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(feature_scaled,labels,test_size=0.3,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
y_pred_test = nb.predict(x_test)
nb_score=nb.score(x_test,y_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
Accuracy_score = accuracy_score(y_test,y_pred_test)
Confusion_matrix = confusion_matrix(y_test,y_pred_test)
Classification_report = classification_report(y_test,y_pred_test)

# %%
Accuracy_score
# Out:
# 0.952513966480447

# %%
print(Confusion_matrix)
# Out:
# [[4675  190]
#  [  65  440]]

# %%
print(Classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      4865
#            1       0.70      0.87      0.78       505
#
#     accuracy                           0.95      5370
#    macro avg       0.84      0.92      0.87      5370
# weighted avg       0.96      0.95      0.95      5370
